# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# !conda install matplotlib
# !pip install matplotlib

# %%
# matplotlib, seaborn, plotly, bokeh

# %% [markdown]
# ## Bar chart

# %%
id1 = np.arange(1,10)
salary = np.arange(20, 110, 10)

# %%
len(id1)
# Out:
# 9

# %%
len(salary)
# Out:
# 9

# %%
plt.figure(figsize=(10,5))

plt.bar(id1, salary)
plt.xlabel('Employee ID')
plt.ylabel('Salaries')
plt.title('Salaries of the employees')
# Out:
# Text(0.5, 1.0, 'Salaries of the employees')

# %%
from turtle import color


plt.figure(figsize=(10,5))

plt.bar(id1, salary, color='#FFA726')
plt.xlabel('Employee ID')
plt.ylabel('Salaries')
plt.title('Salaries of the employees')
# Out:
# Text(0.5, 1.0, 'Salaries of the employees')

# %%
x1 = [1,3, 5, 7]
y1 = [2,4, 6, 8]

x2 = [7,7,7,7]
y2 = [17, 18, 29, 40]

plt.figure(figsize=(10,5))

plt.bar(x1, y1, label='First')
plt.bar(x2, y2, label = 'Second')

plt.xlabel('X')
plt.ylabel('Y')

plt.title('X vs Y')

plt.legend()

# %%
x1 = [1,3, 5, 7]
y1 = [2,4, 6, 8]

x2 = [7,7,7,7]
y2 = [17, 18, 29, 40]

plt.figure(figsize=(10,5))

plt.barh(x1, y1, label='First')
plt.barh(x2, y2, label = 'Second')

plt.xlabel('X')
plt.ylabel('Y')

plt.title('X vs Y')

plt.legend()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.figure(figsize=(8,8))

x = np.arange(1,10)
y = np.random.randint(100,1001,9)

plt.bar(x,y)
plt.title('X vs Y')

for i in range(len(x)):
    plt.text(x[i], y[i] + 10, s=f'{y[i]}', ha='center')


plt.xlabel('Employees')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
x1 = ['Sachin', 'Savin', 'Saurav', 'Rahul']
y1 = [17,18, 459, 20]
y2 = [21, 23, 25, 28]

plt.figure(figsize=(7,5))

plt.bar(x1, y1, label='y1', width=0.5)
plt.bar(x1, y2, label='y2', width=0.5)

plt.legend()

# %% [markdown]
# ## Line graph

# %%
df = pd.DataFrame({'year':[2015, 2016, 2017, 2018],
                   "Salary":[200,300,500,800]})

df
# Out:
#    year  Salary
# 0  2015     200
# 1  2016     300
# 2  2017     500
# 3  2018     800

# %%
plt.figure(figsize=(8,8))

plt.style.use('seaborn-darkgrid')

plt.plot(df['year'],df['Salary'], label='salaries')

plt.legend()

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)

plt.plot(x,y)

plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y, 'r--o')
plt.plot(x,y2,'g-*')

plt.tight_layout()
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y,  linestyle='--')
plt.plot(x,y2,'g-*', linewidth=2)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,5))

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(1,2,1)
plt.plot(x,y1)
plt.subplot(1,2,2)
plt.plot(x,y2)

# %%
x = np.arange(1,10)

y = np.array([x[:i+1].sum() for i in range(len(x))])

# %%
y
# Out:
# array([ 1,  3,  6, 10, 15, 21, 28, 36, 45])

# %%
fig, ax = plt.subplots(2,2, figsize=(12,12))

ax[0,0].plot(x,y)
ax[0,1].bar(x,y)
ax[1,0].plot(x,y**2)
ax[1,1].bar(x, y**2)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ## Scatter plot

# %%
x = np.random.randint(0,100, 100)
y = np.random.randint(0,1000, 100)


fig, ax = plt.subplots(1,2, figsize=(10,5))

ax[0].plot(x, y,color='b')
ax[1].scatter(x,y, color='r')

fig.savefig('sekil 1.png')

# %%
plt.scatter(x,y,s=50)
plt.tight_layout()
plt.xlabel('xtreme positions', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 18.5, 'xtreme positions')

# %% [markdown]
# ## Pie chart/

# %%
area = [48, 32, 20, 15]
labels = ['a', 'c', 'd' ,'e']

plt.figure()
plt.pie(area ,labels=labels, startangle=45, shadow=True, autopct='%.0f%%')

plt.show()

# %% [markdown]
# ## Histogram

# %%
x = np.random.normal(0,10,10000)

plt.hist(x, bins=40)
plt.show()

# %%
x = np.random.uniform(0,10,10000)

plt.hist(x, bins=40)
plt.show()

# %%
averages = []
for i in range(1000):
    averages.append((np.random.choice(x, size=50)).mean())
    
averages = np.array(averages)

plt.hist(averages)
# Out:
# (array([  4.,  16.,  52., 128., 263., 238., 178.,  90.,  27.,   4.]),
#  array([3.52232784, 3.80036959, 4.07841134, 4.35645309, 4.63449484,
#         4.91253659, 5.19057834, 5.4686201 , 5.74666185, 6.0247036 ,
#         6.30274535]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('diamonds')

# absolute path - /users/elnur/updata/python/
# relative path - ../python/datasets/sdfs.csv
# github - raw 
# hazir datasetler -> sklearn.datasets, sns.load_dataset

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
sns.barplot(data=df, x='color', y='carat')
# Out:
# <AxesSubplot:xlabel='color', ylabel='carat'>

# %%
sns.barplot(x=df['cut'], y=df['carat'])
# Out:
# <AxesSubplot:xlabel='cut', ylabel='carat'>

# %%
sns.lineplot(data=df, x='carat', y='price')
# plt.title('Carat vs price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/elnur/Documents/UpData/Data Science Bootcamp/Allahveren bey/Session notes/Matplotlib & Seaborn.ipynb Cell 41 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/elnur/Documents/UpData/Data%20Science%20Bootcamp/Allahveren%20bey/Session%20notes/Matplotlib%20%26%20Seaborn.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> sns.lineplot(data=df, x='carat', y='price')
# ----> <a href='vscode-notebook-cell:/home/elnur/Documents/UpData/Data%20Science%20Bootcamp/Allahveren%20bey/Session%20notes/Matplotlib%20%26%20Seaborn.ipynb#X54sZmlsZQ%3D%3D?line=1'>2</a> plt.title('Carat vs price')
#
# NameError: name 'plt' is not defined

# %%
sns.scatterplot(data=df, x='carat', y='price')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.displot(x=df['carat'])

# %%
df['carat_sqrt'] = df['carat']**0.5

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    carat_sqrt
# 0    0.479583
# 1    0.458258
# 2    0.479583
# 3    0.538516
# 4    0.556776

# %%
sns.histplot(x=df['carat_sqrt'], kde=True)
# Out:
# <AxesSubplot:xlabel='carat_sqrt', ylabel='Count'>

# %%
sns.jointplot(x='carat', y='price', data=df, kind='reg')

# %%
sns.pairplot(df, hue='cut')
