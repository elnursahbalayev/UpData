# %% [markdown]
# # Pandas

# %%
# list
# numpy -> array
# tensorflow -> tensor


# Pandas -> series(1 column), dataframe(cox column)

# %%
import pandas as pd

first_series = pd.Series([1,3,5,7])

# %%
first_series
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
first_series = pd.Series([1,3,5,7], index=['a','b','c','d'])

# %%
first_series
# Out:
# a    1
# b    3
# c    5
# d    7
# dtype: int64

# %%
type(first_series)
# Out:
# pandas.core.series.Series

# %%
data = {'Country':['Brazil', 'China', 'Japan', 'India'],
        'Capital':['Brazil','Beijing','Tokyo', 'New Delhi'],
        'Population':[112312, 12343, 234234, 234892]}

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'Country': ['Brazil', 'China', 'Japan', 'India'],
#  'Capital': ['Brazil', 'Beijing', 'Tokyo', 'New Delhi'],
#  'Population': [112312, 12343, 234234, 234892]}

# %%
df = pd.DataFrame(data)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
df['Country Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country Name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.Country
# Out:
# 0    Brazil
# 1     China
# 2     Japan
# 3     India
# Name: Country, dtype: object

# %%
df.to_numpy()
# Out:
# array([['Brazil', 'Brazil', 112312],
#        ['China', 'Beijing', 12343],
#        ['Japan', 'Tokyo', 234234],
#        ['India', 'New Delhi', 234892]], dtype=object)

# %%
df = pd.read_csv('/home/elnur/Documents/full-stack-data-science/Projects/moviestreams.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/elnur/Documents/UpData/Data Science Bootcamp/Allahveren bey/Session notes/Pandas.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/elnur/Documents/UpData/Data%20Science%20Bootcamp/Allahveren%20bey/Session%20notes/Pandas.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('moviestreams.csv')
#       <a href='vscode-notebook-cell:/home/elnur/Documents/UpData/Data%20Science%20Bootcamp/Allahveren%20bey/Session%20notes/Pandas.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> df.head()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aliyusifov99/python_course/main/Titanic.csv?token=GHSAT0AAAAAABZE4Z57OYQZWTMUDN3AN4OUYZZP32Q')
df.head()
# Out:
#    No.  Survived  Pclass     Sex   Age  SibSp  PrCh   Fare
# 0    1         0       3    male  22.0      1     0   7.25
# 1    2         1       1  female  38.0      1     0  71.28
# 2    3         1       3  female  26.0      0     0   7.93
# 3    4         1       1  female  35.0      1     0  53.10
# 4    5         0       3    male  35.0      0     0   8.05

# %%
df = pd.read_excel('teze.xlsx')

# %%
import mysql.connector

# %%
# connection 
# cursor

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1999"
)

# %%
curr = conn.cursor()

# %%
query = """use sql_store; select * from customers
sdfkjsdklklsdjfklsf"""

curr.execute(query)

# %%
results = curr.fetchall()

# %%
for x in results:
    print(x)
# Out:
# (1, 'Babara', 'MacCaffrey', datetime.date(1986, 3, 28), '781-932-9754', '0 Sage Terrace', 'Waltham', 'VA', 2273)
# (2, 'Ines', 'Brushfield', datetime.date(1986, 4, 13), '804-427-9456', '14187 Commercial Trail', 'Hampton', 'VA', 947)
# (3, 'Freddi', 'Boagey', datetime.date(1985, 2, 7), '719-724-7869', '251 Springs Junction', 'Colorado Springs', 'CO', 2967)
# (4, 'Ambur', 'Roseburgh', datetime.date(1974, 4, 14), '407-231-8017', '30 Arapahoe Terrace', 'Orlando', 'FL', 457)
# (5, 'Clemmie', 'Betchley', datetime.date(1973, 11, 7), None, '5 Spohn Circle', 'Arlington', 'TX', 3675)
# (6, 'Elka', 'Twiddell', datetime.date(1991, 9, 4), '312-480-8498', '7 Manley Drive', 'Chicago', 'IL', 3073)
# (7, 'Ilene', 'Dowson', datetime.date(1964, 8, 30), '615-641-4759', '50 Lillian Crossing', 'Nashville', 'TN', 1672)
# (8, 'Thacher', 'Naseby', datetime.date(1993, 7, 17), '941-527-3977', '538 Mosinee Center', 'Sarasota', 'FL', 205)
# ...

# %%
import pandas as pd

pd.DataFrame(results, columns=[''])
# Out:
#      0        1            2           3             4  \
# 0    1   Babara   MacCaffrey  1986-03-28  781-932-9754
# 1    2     Ines   Brushfield  1986-04-13  804-427-9456
# 2    3   Freddi       Boagey  1985-02-07  719-724-7869
# 3    4    Ambur    Roseburgh  1974-04-14  407-231-8017
# 4    5  Clemmie     Betchley  1973-11-07          None
# 5    6     Elka     Twiddell  1991-09-04  312-480-8498
# 6    7    Ilene       Dowson  1964-08-30  615-641-4759
# 7    8  Thacher       Naseby  1993-07-17  941-527-3977
# 8    9   Romola       Rumgay  1992-05-23  559-181-3744
# 9   10     Levy       Mynett  1969-10-13  404-246-3370
# 10  11    Elnur  Shahbalayev  1999-11-14     773061366
#
#                          5                 6   7     8
# 0           0 Sage Terrace           Waltham  VA  2273
# 1   14187 Commercial Trail           Hampton  VA   947
# 2     251 Springs Junction  Colorado Springs  CO  2967
# 3      30 Arapahoe Terrace           Orlando  FL   457
# ...

# %%
conn.commit()
conn.close()

# %%
df = pd.read_csv('/home/elnur/Documents/full-stack-data-science/Projects/moviestreams.csv')
df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16145 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
df.shape
# Out:
# (16744, 17)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16744, step=1)

# %%
df.columns[:-1]
# Out:
# Index(['Unnamed: 0', 'ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes',
#        'Netflix', 'Hulu', 'Prime Video', 'Disney+', 'Type', 'Directors',
#        'Genres', 'Country', 'Language'],
#       dtype='object')

# %%
df.count()['Age']
# Out:
# 7354

# %%
df['Year'].min()
# Out:
# 1902

# %%
df['Year'].max()
# Out:
# 2020

# %%
df['Year'].mean()
# Out:
# 2003.0140348781654

# %%
df['Year'].std()
# Out:
# 20.674321364090932

# %%
df.describe()
# Out:
#          Unnamed: 0            ID          Year          IMDb       Netflix  \
# count  16744.000000  16744.000000  16744.000000  16173.000000  16744.000000
# mean    8371.500000   8372.500000   2003.014035      5.902751      0.212613
# std     4833.720789   4833.720789     20.674321      1.347867      0.409169
# min        0.000000      1.000000   1902.000000      0.000000      0.000000
# 25%     4185.750000   4186.750000   2000.000000      5.100000      0.000000
# 50%     8371.500000   8372.500000   2012.000000      6.100000      0.000000
# 75%    12557.250000  12558.250000   2016.000000      6.900000      0.000000
# max    16743.000000  16744.000000   2020.000000      9.300000      1.000000
#
#                Hulu   Prime Video       Disney+     Type       Runtime
# count  16744.000000  16744.000000  16744.000000  16744.0  16152.000000
# mean       0.053930      0.737817      0.033684      0.0     93.413447
# std        0.225886      0.439835      0.180419      0.0     28.219222
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0             0
# ID                     0
# Title                  0
# Year                   0
# Age                 9390
# IMDb                 571
# Rotten Tomatoes    11586
# Netflix                0
# Hulu                   0
# Prime Video            0
# Disney+                0
# Type                   0
# Directors            726
# Genres               275
# Country              435
# Language             599
# Runtime              592
# dtype: int64

# %%
11586/16744*100
# Out:
# 69.19493549928333

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aliyusifov99/python_course/main/Titanic.csv?token=GHSAT0AAAAAABZE4Z57OYQZWTMUDN3AN4OUYZZP32Q')
df.head()
# Out:
#    No.  Survived  Pclass     Sex   Age  SibSp  PrCh   Fare
# 0    1         0       3    male  22.0      1     0   7.25
# 1    2         1       1  female  38.0      1     0  71.28
# 2    3         1       3  female  26.0      0     0   7.93
# 3    4         1       1  female  35.0      1     0  53.10
# 4    5         0       3    male  35.0      0     0   8.05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       714 non-null    int64
#  1   Survived  714 non-null    int64
#  2   Pclass    714 non-null    int64
#  3   Sex       714 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     714 non-null    int64
#  6   PrCh      714 non-null    int64
#  7   Fare      714 non-null    float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 44.8+ KB

# %%
df.corr()
# Out:
#                No.  Survived    Pclass       Age     SibSp      PrCh      Fare
# No.       1.000000  0.029720 -0.035380  0.036522 -0.083255 -0.011659  0.009284
# Survived  0.029720  1.000000 -0.359653 -0.077221 -0.017358  0.093317  0.268186
# Pclass   -0.035380 -0.359653  1.000000 -0.369226  0.067247  0.025683 -0.554174
# Age       0.036522 -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096062
# SibSp    -0.083255 -0.017358  0.067247 -0.308247  1.000000  0.383820  0.138334
# PrCh     -0.011659  0.093317  0.025683 -0.189119  0.383820  1.000000  0.205123
# Fare      0.009284  0.268186 -0.554174  0.096062  0.138334  0.205123  1.000000

# %%
df_sex = pd.get_dummies(df['Sex'])

# %%
df['male'] = df_sex['male']
df['female'] =df_sex['female']

# %%
df.head()
# Out:
#    No.  Survived  Pclass     Sex   Age  SibSp  PrCh   Fare  male  female
# 0    1         0       3    male  22.0      1     0   7.25     1       0
# 1    2         1       1  female  38.0      1     0  71.28     0       1
# 2    3         1       3  female  26.0      0     0   7.93     0       1
# 3    4         1       1  female  35.0      1     0  53.10     0       1
# 4    5         0       3    male  35.0      0     0   8.05     1       0

# %%
df.corr()
# Out:
#                No.  Survived    Pclass       Age     SibSp      PrCh  \
# No.       1.000000  0.029720 -0.035380  0.036522 -0.083255 -0.011659
# Survived  0.029720  1.000000 -0.359653 -0.077221 -0.017358  0.093317
# Pclass   -0.035380 -0.359653  1.000000 -0.369226  0.067247  0.025683
# Age       0.036522 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp    -0.083255 -0.017358  0.067247 -0.308247  1.000000  0.383820
# PrCh     -0.011659  0.093317  0.025683 -0.189119  0.383820  1.000000
# Fare      0.009284  0.268186 -0.554174  0.096062  0.138334  0.205123
# male      0.024050 -0.538826  0.155460  0.093254 -0.103950 -0.246972
# female   -0.024050  0.538826 -0.155460 -0.093254  0.103950  0.246972
#
#               Fare      male    female
# No.       0.009284  0.024050 -0.024050
# Survived  0.268186 -0.538826  0.538826
# Pclass   -0.554174  0.155460 -0.155460
# Age       0.096062  0.093254 -0.093254
# SibSp     0.138334 -0.103950  0.103950
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df["Pclass"][100]
# Out:
# 3

# %%
df[df['Pclass'].isna() == False]['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 709    3
# 710    2
# 711    1
# 712    1
# 713    3
# Name: Pclass, Length: 714, dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [No., Survived, Pclass, Sex, Age, SibSp, PrCh, Fare, male, female]
# Index: []

# %%
df
# Out:
#      No.  Survived  Pclass     Sex   Age  SibSp  PrCh   Fare  male  female
# 0      1         0       3    male  22.0      1     0   7.25     1       0
# 1      2         1       1  female  38.0      1     0  71.28     0       1
# 2      3         1       3  female  26.0      0     0   7.93     0       1
# 3      4         1       1  female  35.0      1     0  53.10     0       1
# 4      5         0       3    male  35.0      0     0   8.05     1       0
# ..   ...       ...     ...     ...   ...    ...   ...    ...   ...     ...
# 709  710         0       3  female  39.0      0     5  29.13     0       1
# 710  711         0       2    male  27.0      0     0  13.00     1       0
# 711  712         1       1  female  19.0      0     0  30.00     0       1
# 712  713         1       1    male  26.0      0     0  30.00     1       0
# 713  714         0       3    male  32.0      0     0   7.75     1       0
#
# [714 rows x 10 columns]

# %%
df.loc[4,'SibSp']
# Out:
# 0

# %%
df.iloc[[4],[5]]
# Out:
#    SibSp
# 4      0

# %%
df.sort_values(by='Age', inplace=True)

# %%
df
# Out:
#      No.  Survived  Pclass     Sex    Age  SibSp  PrCh   Fare  male  female
# 640  641         1       3    male   0.42      0     1   8.52     1       0
# 602  603         1       2    male   0.67      1     1  14.50     1       0
# 509  510         1       3  female   0.75      2     1  19.26     0       1
# 374  375         1       3  female   0.75      2     1  19.26     0       1
# 59    60         1       2    male   0.83      0     2  29.00     1       0
# ..   ...       ...     ...     ...    ...    ...   ...    ...   ...     ...
# 91    92         0       3    male  70.50      0     0   7.75     1       0
# 393  394         0       1    male  71.00      0     0  49.50     1       0
# 74    75         0       1    male  71.00      0     0  34.65     1       0
# 679  680         0       3    male  74.00      0     0   7.78     1       0
# 498  499         1       1    male  80.00      0     0  30.00     1       0
#
# [714 rows x 10 columns]

# %%
df.loc[4,'Age']
# Out:
# 35.0

# %%
df.iloc[[4],[4]]
# Out:
#      Age
# 59  0.83

# %%
df[df['Pclass'].unique()[0] == df['Pclass']]
# Out:
#      No.  Survived  Pclass     Sex    Age  SibSp  PrCh   Fare  male  female
# 640  641         1       3    male   0.42      0     1   8.52     1       0
# 509  510         1       3  female   0.75      2     1  19.26     0       1
# 374  375         1       3  female   0.75      2     1  19.26     0       1
# 305  306         1       3  female   1.00      0     2  15.74     0       1
# 132  133         0       3    male   1.00      4     1  39.69     1       0
# ..   ...       ...     ...     ...    ...    ...   ...    ...   ...     ...
# 262  263         0       3    male  61.00      0     0   6.24     1       0
# 385  386         1       3  female  63.00      0     0   9.59     0       1
# 225  226         0       3    male  65.00      0     0   7.75     1       0
# 91    92         0       3    male  70.50      0     0   7.75     1       0
# 679  680         0       3    male  74.00      0     0   7.78     1       0
#
# [355 rows x 10 columns]

# %%
df['Pclass'].nunique()
# Out:
# 3

# %%
df.head()
# Out:
#      No.  Survived  Pclass     Sex   Age  SibSp  PrCh   Fare  male  female
# 640  641         1       3    male  0.42      0     1   8.52     1       0
# 602  603         1       2    male  0.67      1     1  14.50     1       0
# 509  510         1       3  female  0.75      2     1  19.26     0       1
# 374  375         1       3  female  0.75      2     1  19.26     0       1
# 59    60         1       2    male  0.83      0     2  29.00     1       0

# %%
df.tail()
# Out:
#      No.  Survived  Pclass   Sex   Age  SibSp  PrCh   Fare  male  female
# 91    92         0       3  male  70.5      0     0   7.75     1       0
# 393  394         0       1  male  71.0      0     0  49.50     1       0
# 74    75         0       1  male  71.0      0     0  34.65     1       0
# 679  680         0       3  male  74.0      0     0   7.78     1       0
# 498  499         1       1  male  80.0      0     0  30.00     1       0

# %%
df.sample(5)
# Out:
#      No.  Survived  Pclass     Sex   Age  SibSp  PrCh    Fare  male  female
# 142  143         0       1  female  50.0      0     0   28.71     0       1
# 227  228         0       3    male  16.0      0     0    9.50     1       0
# 680  681         0       3  female   9.0      1     1   15.25     0       1
# 635  636         0       3    male  30.0      0     0    7.23     1       0
# 301  302         0       1    male  27.0      0     2  211.50     1       0

# %%
df[df['Age']>50]
# Out:
#      No.  Survived  Pclass     Sex   Age  SibSp  PrCh   Fare  male  female
# 125  126         0       1    male  51.0      0     1  61.38     1       0
# 179  180         0       3    male  51.0      0     0   8.05     1       0
# 611  612         1       1  female  51.0      1     0  77.96     0       1
# 499  500         0       3    male  51.0      0     0   7.05     1       0
# 328  329         0       3    male  51.0      0     0   7.75     1       0
# ..   ...       ...     ...     ...   ...    ...   ...    ...   ...     ...
# 91    92         0       3    male  70.5      0     0   7.75     1       0
# 393  394         0       1    male  71.0      0     0  49.50     1       0
# 74    75         0       1    male  71.0      0     0  34.65     1       0
# 679  680         0       3    male  74.0      0     0   7.78     1       0
# 498  499         1       1    male  80.0      0     0  30.00     1       0
#
# [64 rows x 10 columns]

# %%
df[df['Age']>50][['Sex','Age']]
# Out:
#         Sex   Age
# 125    male  51.0
# 179    male  51.0
# 611  female  51.0
# 499    male  51.0
# 328    male  51.0
# ..      ...   ...
# 91     male  70.5
# 393    male  71.0
# 74     male  71.0
# 679    male  74.0
# 498    male  80.0
#
# [64 rows x 2 columns]

# %%
df.sort_values(by='Age',ascending=False, inplace=True)

# %%
df
# Out:
#      No.  Survived  Pclass     Sex    Age  SibSp  PrCh   Fare  male  female
# 498  499         1       1    male  80.00      0     0  30.00     1       0
# 679  680         0       3    male  74.00      0     0   7.78     1       0
# 74    75         0       1    male  71.00      0     0  34.65     1       0
# 393  394         0       1    male  71.00      0     0  49.50     1       0
# 91    92         0       3    male  70.50      0     0   7.75     1       0
# ..   ...       ...     ...     ...    ...    ...   ...    ...   ...     ...
# 664  665         1       2    male   0.83      1     1  18.75     1       0
# 509  510         1       3  female   0.75      2     1  19.26     0       1
# 374  375         1       3  female   0.75      2     1  19.26     0       1
# 602  603         1       2    male   0.67      1     1  14.50     1       0
# 640  641         1       3    male   0.42      0     1   8.52     1       0
#
# [714 rows x 10 columns]

# %%
df.sort_index(inplace=True)

# %%
df.rename(columns={'Sex':'Gender'}, inplace=True)

# %%
df.head()
# Out:
#    No.  Survived  Pclass  Gender   Age  SibSp  PrCh   Fare  male  female
# 0    1         0       3    male  22.0      1     0   7.25     1       0
# 1    2         1       1  female  38.0      1     0  71.28     0       1
# 2    3         1       3  female  26.0      0     0   7.93     0       1
# 3    4         1       1  female  35.0      1     0  53.10     0       1
# 4    5         0       3    male  35.0      0     0   8.05     1       0

# %%
df['Teze'] = pd.Series(df['Age'].to_numpy().mean())

# %%
df.head()
# Out:
#    No.  Survived  Pclass  Gender   Age  SibSp  PrCh   Fare  male  female  \
# 0    1         0       3    male  22.0      1     0   7.25     1       0
# 1    2         1       1  female  38.0      1     0  71.28     0       1
# 2    3         1       3  female  26.0      0     0   7.93     0       1
# 3    4         1       1  female  35.0      1     0  53.10     0       1
# 4    5         0       3    male  35.0      0     0   8.05     1       0
#
#         Teze
# 0  29.699118
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.columns = df.columns.str.title()

# %%
df
# Out:
#      No.  Survived  Pclass  Gender   Age  Sibsp  Prch   Fare  Male  Female  \
# 0      1         0       3    male  22.0      1     0   7.25     1       0
# 1      2         1       1  female  38.0      1     0  71.28     0       1
# 2      3         1       3  female  26.0      0     0   7.93     0       1
# 3      4         1       1  female  35.0      1     0  53.10     0       1
# 4      5         0       3    male  35.0      0     0   8.05     1       0
# ..   ...       ...     ...     ...   ...    ...   ...    ...   ...     ...
# 709  710         0       3  female  39.0      0     5  29.13     0       1
# 710  711         0       2    male  27.0      0     0  13.00     1       0
# 711  712         1       1  female  19.0      0     0  30.00     0       1
# 712  713         1       1    male  26.0      0     0  30.00     1       0
# 713  714         0       3    male  32.0      0     0   7.75     1       0
#
#           Teze
# 0    29.699118
# 1          NaN
# 2          NaN
# ...

# %%
df = pd.read_csv('/home/elnur/Documents/full-stack-data-science/Projects/moviestreams.csv')
df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
df['Age'] = df['Age'].str.replace('+','')
# Out:
# /tmp/ipykernel_32673/3409114605.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Age'] = df['Age'].str.replace('+','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16145 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
df['Age'].dropna(inplace=True, how='Any', axis=0)

# %%
df['Age']

# %%
df['Age'] = df['Age'].dropna(how='any', inplace=True)

# %%
df['Age'].isna().sum()
# Out:
# 9390

# %%
df['Age'].isna().sum()
# Out:
# 16744

# %%
df['Age']
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 16739    None
# 16740    None
# 16741    None
# 16742    None
# 16743    None
# Name: Age, Length: 16744, dtype: object
